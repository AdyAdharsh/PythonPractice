# %% [markdown]
# # Day1 Intro
#
# 🗓️ Date:
#
# ---
# ## 🎯 Learning Objectives
# -
# -
#
# ## 🧠 Notes
#
#
# ## 💻 Practice Code
#
#
# ## ✅ Summary

# %%
for i in range(3): 
    print("Hello!")
# Out:
# Hello!
# Hello!
# Hello!

# %% [markdown]
# Containers

# %%
a_tuple = (1,2,3, 'a string')
a_list = [1,2,3, 'a list']

print(a_tuple[3])
print(len(a_list))
# Out:
# a string
# 4
