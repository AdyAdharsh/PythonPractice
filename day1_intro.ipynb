# %% [markdown]
# # Day1 Intro
#
# 🗓️ Date:
#
# ---
# ## 🎯 Learning Objectives
# -
# -
#
# ## 🧠 Notes
#
#
# ## 💻 Practice Code
#
#
# ## ✅ Summary

# %%
for i in range(3): 
    print("Hello!")
# Out:
# Hello!
# Hello!
# Hello!

# %% [markdown]
# Containers

# %%
a_tuple = (1,2,3, 'a string')
a_list = [1,2,3, 'a list']

print(a_tuple[3])
print(len(a_list))
# Out:
# a string
# 4

# %%
data = {'key1': 'main door access', 'key2': 'server room access', 'key3': 'main office access'}
length = len(data)

for i in range(length):
    print(f"Index {i} holds value: {data[f'key{i+1}']}")
# Out:
# Index 0 holds value: main door access
# Index 1 holds value: server room access
# Index 2 holds value: main office access

# %% [markdown]
# Write a for loop that uses the single-argument range() function to print the phrase "Loop Cycle [Number]" five times.
#
# The counter number should start at 0 and go up to 4.

# %%
for i in range(5):
    print(f"loop in: {i}")
# Out:
# loop in: 0
# loop in: 1
# loop in: 2
# loop in: 3
# loop in: 4

# %% [markdown]
# Task 2: Specific Start and Stop (range(start, stop))
# Write a for loop that uses the two-argument range() function to print only the even numbers between 10 and 17 (inclusive).
#
# Hint: You'll need to start at 10 and check each number inside the loop to see if it's even (if i % 2 == 0).

# %%
for i in range(10, 17):
    if i % 2 == 0:
        print(f"even number: {i}")
# Out:
# even number: 10
# even number: 12
# even number: 14
# even number: 16

# %%
for i in range(10, 17):
    if i % 2 == 0:
        print(f"even number: {i}")
# Out:
# even number: 10
# even number: 12
# even number: 14
# even number: 16

# %%
class Greeter():
    def say_hello(self, name):
        greeting = f"hello, {name}! Welcome to the system."
        return greeting

my_greeter = Greeter()
message = my_greeter.say_hello("Alice")
print(message)
# Out:
# hello, Alice! Welcome to the system.

# %% [markdown]
# 📐 Task: The Rectangle Calculator
# Your goal is to create a class that models a rectangle and has a method to calculate its area.
#
# 🎯 Requirements
# Define a Class: Name it Rectangle.
#
# Define a Method: Name it calculate_area.
#
# Use Parameters: The method should accept two required parameters (in addition to self):
#
# length
#
# width
#
# Write the Logic/Return: The method must calculate the area (length multiplied by width) and use the return keyword to output the result.
#
# 🪜 Your Steps
# You should follow the 6 steps we discussed to complete this task:
#
# Define the Class (class Rectangle:)
#
# Define the Method (def calculate_area(...))
#
# Write the Logic/Return (Use the parameters to calculate the area)
#
# Create the Object (e.g., my_rect = Rectangle())
#
# Call the Method (Pass in two arguments for length and width)
#
# Output (e.g., Printing) (Print the result)

# %%
class Rectangle():
    def calculate_area(self, length, width):
        output = f"area of rectangle is multipled by length {length} * width {width} = {length * width}"
        return output
my_rect = (Rectangle())
area_message = my_rect.calculate_area(5, 10)
area_message1 = my_rect.calculate_area(7, 3)
print(area_message)
print(area_message1)
# Out:
# area of rectangle is multipled by length 5 * width 10 = 50
# area of rectangle is multipled by length 7 * width 3 = 21

# %%
class Account():
    def __init__(self, owner_name, initial_balance):
        self.owner_name = owner_name
        self.balance = initial_balance
    def check_balance(self):
            return(f"The owner is {self.owner_name} with balance {self.balance}")

my_account = Account("Alice", 1000)
accountbalance = my_account.check_balance()
print(accountbalance)
# Out:
# The owner is Alice with balance 1000

# %%
class Account():
    def __init__(self, owner_name, initial_balance):
        self.owner_name = owner_name
        self.balance = initial_balance
    def check_balance(self):
            return(f"The owner is {self.owner_name} with balance {self.balance}")

my_account = Account("Alice", 1000)
accountbalance = my_account.check_balance()
print(accountbalance)
# Out:
# The owner is Alice with balance 1000

# %%
# --- Test Case 1: Student (Should be True) ---
age_1 = 17
is_student_1 = True

# Breakdown of the logic:
# ((17 >= 10) and (17 <= 20) and True) OR (17 >= 65)
# (True and True and True) OR (False)
# True OR False  ==> True
is_discount_eligible_1 = (age_1 >= 10 and age_1 <= 20 and is_student_1) or (age_1 >= 65)
print(f"Test 1 (Student): {is_discount_eligible_1}")
# Out:
# Test 1 (Student): True

# %%
def check_ticket_discount(age, is_student):
    is_eligible_student = (age >= 10 and age <= 20 and is_student)

    is_eligible_senior = (age >= 65)

    return is_eligible_student or is_eligible_senior

# 1. Teen Student (16, True) - Should be True
print(f"Test 1: {check_ticket_discount(16, True)}")

# 2. Young Adult (25, False) - Should be False
print(f"Test 2: {check_ticket_discount(25, False)}")

# 3. Senior (68, True) - Should be True
print(f"Test 3: {check_ticket_discount(68, True)}")

# 4. Non-student Teen (14, False) - Should be False
print(f"Test 4: {check_ticket_discount(14, False)}")
# Out:
# Test 1: True
# Test 2: False
# Test 3: True
# Test 4: False

# %%
def check_free_shipping(order_price, order_weight, membership_status):
    is_customer_eligible = (order_price > 10) and (order_weight <= 150)
    is_premium_member = (membership_status == "Premium")
    return is_customer_eligible or is_premium_member

# %%
def is_password_strong(password):
    is_long_enough = len(password) > 8
    is_complex = any(char.isupper() for char in password) or any(char.isdigit() for char in password)
    return is_long_enough and is_complex

# %%
def check_restock_alert(inventory_list):
    """
    Identifies items requiring a restock alert based on low stock and high demand.

    Args:
        inventory_list (list): A list of item dictionaries.

    Returns:
        list: A list of item names that need a restock alert.
    """
    restock_alerts = [] # This list will hold the names of the flagged items

    for item in inventory_list:
        # 1. Extract necessary variables for clarity
        quantity = item["stock"]
        demand = item["sales"]
        status = item["status"]

        # 2. Apply ALL restock alert conditions (must be True for the alert to trigger)
        # Condition 1: Low Quantity (stock < 15)
        # Condition 2: High Demand (sales >= 10)
        # Condition 3: No Backorder (status != "Backordered")
        is_alert = (quantity < 15) and (demand >= 10) and (status != "Backordered")

        # 3. Conditional Appending
        if is_alert:
            restock_alerts.append(item["name"])

    return restock_alerts

# --- Testing the function with the provided data ---
inventory_data = [
    {"name": "Widget A", "stock": 10, "sales": 20, "status": "In Stock"},
    {"name": "Gadget B", "stock": 50, "sales": 5, "status": "In Stock"},
    {"name": "Thing C", "stock": 12, "sales": 15, "status": "Backordered"},
    {"name": "Doodad D", "stock": 5, "sales": 18, "status": "In Stock"},
]

print(check_restock_alert(inventory_data))
# Out:
# ['Widget A', 'Doodad D']

# %%
class Thermostat:
    # 1. Class Attributes (MIN/MAX_TEMP)
    MIN_TEMP = 10
    MAX_TEMP = 30

    def __init__(self):
        # 2. Initialize private instance attribute
        # Starts the target temperature at 20 degrees.
        self._target_temp = 20

    # 3. Getter method
    def get_target_temp(self):
        # Returns the current private target temperature.
        return self._target_temp

    # 4. Setter method with safety logic
    def set_target_temp(self, new_temp):
        # The safety check uses an 'or' operator:
        # If the new_temp is too low OR too high, the 'if' condition is True.
        if new_temp < self.MIN_TEMP or new_temp > self.MAX_TEMP:
            print(f"Error: Temperature {new_temp} out of safe bounds. Must be between {self.MIN_TEMP}°C and {self.MAX_TEMP}°C.")
        else:
            # If the temperature is safe, update the private attribute.
            self._target_temp = new_temp
            print(f"Target set to {new_temp}°C.")

# %%
class Calculator:

    def __init__(self):
        # Initializes the private internal value to 0
        self._current_value = 0

    def get_current_value(self):
        # CORRECTION: Must accept 'self' as a parameter.
        # This is the "Getter" method.
        return self._current_value

    def add(self, number):
        # CORRECT LOGIC: Update the object's internal state.
        # It adds the 'number' argument to the existing '_current_value'.
        self._current_value += number

    def subtract(self, number):
        # CORRECT LOGIC: Update the object's internal state.
        # It subtracts the 'number' argument from the existing '_current_value'.
        self._current_value -= number

my_calc = Calculator()

# 6. Perform a sequence of operations
print("Starting value:", my_calc.get_current_value()) # Should print 0

my_calc.add(50+20)
print("After adding 50:", my_calc.get_current_value()) # Should print 50

my_calc.subtract(12)
print("After subtracting 12:", my_calc.get_current_value()) # Should print 38

my_calc.add(4)
print("After adding 4:", my_calc.get_current_value()) # Should print 42

# 7. Print the final result
print("\nFinal Result:", my_calc.get_current_value())
# Out:
# Starting value: 0
# After adding 50: 70
# After subtracting 12: 58
# After adding 4: 62
#
# Final Result: 62

# %%
def double_money(amount):
    # Method Logic: Define the simple rule for the action.
    result = amount * 2
    return result
print(double_money(50))  # Expected output: 100
# Out:
# 100

# %%
def print_names_fast(names):
    # This method is O(n) - Linear Time
    # The work grows directly with the size of the list.
    
    for name in names: # Loop 1 (Runs N times)
        print("Hello,", name)

# %%
def find_two_sum(number_list, target_sum):
    numbers_seen = {}
    for index, current_num in enumerate(number_list):
        complement_needed = target_sum - current_num
        if complement_needed in numbers_seen:
            complement_index = numbers_seen[complement_needed]
            current_index = index
            return [complement_index, current_index]
        numbers_seen[current_num] = index
    return []
numbers = [3, 5, 2, 8]
target = 10 

result = find_two_sum(numbers, target)
print(f"The indices are: {result}")
# Out:
# The indices are: [2, 3]

# %%
def find_three_sum(number_)

# %%
# --- Core Logic Block ---

def find_pair_indices(full_list, desired_total):
    
    # This dictionary is our "Memory Bank" or "Scratchpad."
    # We store numbers we've already checked here for fast lookups.
    # Key = The number we've seen.
    # Value = The index (position) where we saw it.
    memory_of_numbers = {}

    # Iterate through the list, getting both the position and the number itself.
    for current_index, current_number in enumerate(full_list):

        # 1. LOGIC STEP: Determine the required partner
        # This is the specific number we NEED to find to hit the desired_total.
        partner_needed = desired_total - current_number

        # 2. CHECK THE MEMORY: Have we seen the partner_needed before?
        if partner_needed in memory_of_numbers:
            
            # SUCCESS! The partner is in the dictionary.
            
            # The partner's index is stored as the value in our dictionary.
            partner_index = memory_of_numbers[partner_needed]
            
            # The current number's index is 'current_index'.
            
            # Return both indices as the final answer.
            return [partner_index, current_index]

        # 3. UPDATE MEMORY: If no pair was found, add the current number to the bank
        # We store the current number as the key and its position as the value.
        memory_of_numbers[current_number] = current_index

    # If the loop finishes without finding a pair, return an empty list.
    return []

# --- Example Usage ---
my_list = [1, 9, 3, 7]
target_value = 10
result = find_pair_indices(my_list, target_value)
print(result) # Output: [1, 3] because 9 (index 1) + 7 (index 3) = 10
# Out:
# [0, 1]

# %%
class Solution:
       def twoSum(self, nums: list[int], target: int) -> list[int]:
          prevMap = {} # Initialize a dictionary (hash map) to store (value, index)
          for i, n in enumerate(nums): # Loop through the list with index i and value n
             diff = target - n # Calculate the required difference
             if diff in prevMap: # Check if the difference needed is already in the map
                return [prevMap[diff], i] # Found the pair: return the stored index and the current index
             prevMap[n] = i # If not found, add the current number and its index to the map
          
          return [] # Only return an empty list if the loop completes without finding a solution

# Example execution
List = [-2, 1, 0, 4, -3]
target = 1
result = Solution().twoSum(List, target)
print(result)
# Out:
# [1, 2]

# %%
class find_reminder:
    def isevn(n):
        rem = n % 2
        if rem == 0:
            return True
        else:
            return False

result = find_reminder.isevn(4)
print(result)
# Out:
# True

# %%
class tables():
    def multipletable(n):
        for i in range(1, 11):
            n = i+1
            print(f"2 * {n} = {2*n}")

result = tables.multipletable(2)
print(result)
# Out:
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20
# 2 * 11 = 22
# None

# %%
class tables():
    def multipletable(n):
        for i in range(1, 11):
            n = i+1
            print(f"2 * {n} = {2*n}")

result = tables.multipletable(22)
print(result)
# Out:
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20
# 2 * 11 = 22
# None

# %%
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name} is {self.age} years old."
dog1 = Dog("Buddy", 3)
dog2 = Dog("Charlie", 5)

print(dog1)  
print(dog2)
# Out:
# Buddy is 3 years old.
# Charlie is 5 years old.

# %%
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"{self.name} is {self.age} years old."
dog1 = Dog("Buddy", 3)
dog2 = Dog("Charlie", 5)

print(dog1)  
print(dog2)

# %%
# THE PARENT
class Phone:
    def display_message(self):
        print("Message: Battery Low.")

# THE CHILD (Overrides the message)
class SmartPhone(Phone):
    def display_message(self):
        # This replaces the Parent's version entirely
        print("Notification: You have 5 new Instagram likes!")

# --- EXECUTION ---
basic_phone = Phone()
my_iphone = SmartPhone()

basic_phone.display_message() # Output: Message: Battery Low.
my_iphone.display_message()   # Output: Notification: You have 5 new Instagram likes!
# Out:
# Message: Battery Low.
# Notification: You have 5 new Instagram likes!

# %%
# THE PARENT
class Phone:
    def display_message(self):
        print("Message: Battery Low.")

# THE CHILD (Overrides the message)
class SmartPhone(Phone):
    def display_message(self):
        # This replaces the Parent's version entirely
        print("Notification: You have 5 new Instagram likes!")

# --- EXECUTION ---
basic_phone = Phone()
my_iphone = SmartPhone()

basic_phone.display_message() # Output: Message: Battery Low.
my_iphone.display_message()   # Output: Notification: You have 5 new Instagram likes!
# Out:
# Message: Battery Low.
# Notification: You have 5 new Instagram likes!

# %%
class Dog:
    species = "Canine"  # Class variable
    
    def __init__(self, name, age):
        self.name = name  # Instance variable
        self.age = age  # Instance variable

dog1 = Dog("Buddy", 3)
dog2 = Dog("Lucy", 2)

print(dog1.species)  # Accessing class variable
print(dog2.name)  # Accessing instance variable
# Out:
# Canine
# Lucy

# %%
class Dog:
    species = "Canine"  # Class variable
    
    def __init__(self, name, age):
        self.name = name  # Instance variable
        self.age = age  # Instance variable

dog1 = Dog("Buddy", 3)
dog2 = Dog("Lucy", 2)

print(dog1.species)  # Accessing class variable
print(dog2.name)  # Accessing instance variable
# Out:
# Canine
# Lucy

# %%
class Animal:
    def sound(self):
        print("Some sound")

class Dog(Animal):
    def sound(self):  # Method overriding
        print("Woof")

dog = Dog()
dog.sound()
# Out:
# Woof

# %%
class Dog:
    # Class variable
    species = "Canine"

    def __init__(self, name, age):
        # Instance variables
        self.name = name
        self.age = age

# Create objects
dog1 = Dog("Buddy", 3)
dog2 = Dog("Charlie", 5)

# Access class and instance variables
print(dog1.species)  # (Class variable)
print(dog1.name)     # (Instance variable)
print(dog2.name)     # (Instance variable)

# Modify instance variables
dog1.name = "Max"
print(dog1.name)     # (Updated instance variable)

# Modify class variable
Dog.species = "Feline"
print(dog1.species)  # (Updated class variable)
print(dog2.species)
# Out:
# Canine
# Buddy
# Charlie
# Max
# Feline
# Feline

# %%
# THE PARENT
class Phone:
    def display_message(self):
        print("Message: Battery Low.")

# THE CHILD (Overrides the message)
class SmartPhone(Phone):
    def display_message(self):
        # This replaces the Parent's version entirely
        print("Notification: You have 5 new Instagram likes!")

# --- EXECUTION ---
basic_phone = Phone()
my_iphone = SmartPhone()

basic_phone.display_message() # Output: Message: Battery Low.
my_iphone.display_message()   # Output: Notification: You have 5 new Instagram likes!
# Out:
# Message: Battery Low.
# Notification: You have 5 new Instagram likes!

# %%
# THE PARENT
class Phone:
    def __init__(self, brand):
        self.brand = brand
    
    def call(self, number):
        print(f"Calling {number} from my {self.brand} phone...")

# THE CHILD (Inherits from Phone)
class SmartPhone(Phone): 
    def __init__(self, brand, model):
        # 'super()' tells Python to run the Parent's __init__ too!
        super().__init__(brand) 
        self.model = model
        self.apps = []

    def install_app(self, app_name):
        self.apps.append(app_name)
        print(f"Installing {app_name} on {self.model}...")

# --- EXECUTION ---
my_pixel = SmartPhone("Google", "Pixel 8")

# Even though we didn't write 'call' inside SmartPhone, it still works!
my_pixel.call("911") 
my_pixel.install_app("Instagram")
# Out:
# Calling 911 from my Google phone...
# Installing Instagram on Pixel 8...

# %%
from abc import ABC, abstractmethod
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Dog(Animal):
    def sound(self):
        print("Woof")

dog = Dog()
dog.sound()
# Out:
# Woof

# %%
# THE PARENT
class Phone:
    def display_message(self):
        print("Message: Battery Low.")

# THE CHILD (Overrides the message)
class SmartPhone(Phone):
    def display_message(self):
        # This replaces the Parent's version entirely
        print("Notification: You have 5 new Instagram likes!")

# --- EXECUTION ---
basic_phone = Phone()
my_iphone = SmartPhone()

basic_phone.display_message() # Output: Message: Battery Low.
my_iphone.display_message()   # Output: Notification: You have 5 new Instagram likes!
# Out:
# Message: Battery Low.
# Notification: You have 5 new Instagram likes!

# %%
7 + 3 * 2
# Out:
# 13

# %%
import math

# Square root
print(math.sqrt(16))  # Output: 4.0

# Trigonometry (uses radians)
print(math.sin(math.pi / 2))  # Output: 1.0

# Logarithms (natural log)
print(math.log(math.e))  # Output: 1.0
# Out:
# 4.0
# 1.0
# 1.0

# %% [markdown]
# Printing things and variables (storing information)
# Getting input from a user
# Doing math and comparisons
# If/else (making decisions)
# Loops (repeating things)
# Lists (storing groups of things)
# Functions (reusable blocks of code)

# %%
name = "Adharsh"
favorite_color = "blue"
age = 28

print(f"my name is {name}, favourite colour is {favorite_color} and I am {age} years old.")
# Out:
# my name is Adharsh, favourite colour is blue and I am 28 years old.

# %%
city = "London"
hobby = "swimming"
years_coding = 2

print(f"I live in {city}. i enjoy {hobby} and have been coding for {years_coding}")
# Out:
# I live in London. i enjoy swimming and have been coding for 2

# %%
name = input("What is your name? ")

print(f"welcome to the system, {name}!")
# Out:
# welcome to the system, Adharsh!

# %%
age = input("what is your age?")
age = int(age)

print(f"next year you will be {age + 1}")
# Out:
# next year you will be 29

# %%
name = input("what is your name?")

city = input("which city do you live in")

print(f"Hi {name}, hope you enjoy your time in {city}")
# Out:
# Hi Adharsh, hope you enjoy your time in london

# %%
age = input("what is your age?")
age = int(age)

next_year = age + 1 

print(f"next year you will be {next_year}")
# Out:
# next year you will be 29

# %%
number_1 = input("enter a first number: ")
number_2 = input("enter the next number: ")

multiply = int(number_1) * int(number_2) 

print(f"the multiplication of given two number is {multiply}")
# Out:
# the multiplication of given two number is 264

# %%
number_1 = input("enter a first number: ")
number_2 = input("enter the next number: ")

multiply = int(number_1) * int(number_2) 

add = multiply + 2

print(f"the multiplication of given two number is {multiply}, and adding 2 to it gives {add}")
# Out:
# the multiplication of given two number is 286, and adding 2 to it gives 288

# %%
number = int(input("enter the number: "))

if number > 0:
    print(f"the number is {number} positive")
elif number < 0:
    print(f"the number is {number} negative")
else:
    print(f"the number is zero")
# Out:
# the number is zero

# %%
for i in range(1, 6):
    print(f"the loop number is: {i}")
# Out:
# the loop number is: 1
# the loop number is: 2
# the loop number is: 3
# the loop number is: 4
# the loop number is: 5

# %% [markdown]
# Then, mini exercise:
#
# Use a for loop to print the numbers from 1 to 10, but for each number, also print whether it's even or odd.
# Example output line: "1 is odd", "2 is even"
#
# Hint: you'll need to combine what you learned about loops and conditionals (if/else) and the modulo operator % (a number is even if number % 2 == 0).

# %%
for i in range(1, 11):
    if i % 2 == 0:
        print(f"even number: {i}")
    elif i % 2 != 0:
        print(f"odd number: {i}")

print(f"the last number was: {i}")
# Out:
# odd number: 1
# even number: 2
# odd number: 3
# even number: 4
# odd number: 5
# even number: 6
# odd number: 7
# even number: 8
# odd number: 9
# even number: 10
# the loop number is: 10

# %%
fruits = ["apple", "banana", "cherry"]

for fruit in fruits:
    print(fruit)
fruits.append("orange")
print(len(fruits))
print(fruits[-1])
# Out:
# apple
# banana
# cherry
# 4
# orange

# %%
list = [1, 2, 3, 4, 5]
for item in list:
    if item < 5:
        print(f"the {item} is lesser than 5")
# Out:
# the 1 is lesser than 5
# the 2 is lesser than 5
# the 3 is lesser than 5
# the 4 is lesser than 5

# %%
numbers = [1, 2, 3, 4, 5, 15, 20]

for item in numbers:
    if item > 10:
        print(f"{item} is greater than 10")
    else:
        print(f"{item} is not greater than 10")
# Out:
# 1 is not greater than 10
# 2 is not greater than 10
# 3 is not greater than 10
# 4 is not greater than 10
# 5 is not greater than 10
# 15 is greater than 10
# 20 is greater than 10

# %%
for i in range(1, 21):
    if i % 3 == 0 and i % 5 == 0:
        print(f"the number {i} is divisible by both 3 and 5 so fizzbuzz")
    elif i % 3 == 0:
        print(f"the number {i} is divisible by 3 so fizz")
    elif i % 5 == 0:
        print(f"the number {i} is divisible by 5 so buzz")
    else:
        print(f"the number {i} is just {i}")
# Out:
# the number 1 is just 1
# the number 2 is just 2
# the number 3 is divisible by 3 so fizz
# the number 4 is just 4
# the number 5 is divisible by 5 so buzz
# the number 6 is divisible by 3 so fizz
# the number 7 is just 7
# the number 8 is just 8
# the number 9 is divisible by 3 so fizz
# the number 10 is divisible by 5 so buzz
# the number 11 is just 11
# the number 12 is divisible by 3 so fizz
# the number 13 is just 13
# the number 14 is just 14
# the number 15 is divisible by both 3 and 5 so fizzbuzz
# the number 16 is just 16
# the number 17 is just 17
# the number 18 is divisible by 3 so fizz
# the number 19 is just 19
# the number 20 is divisible by 5 so buzz

# %%
def is_even(number):
    return number % 2 == 0 
    
print(is_even(4))
print(is_even(5))
# Out:
# True
# False

# %%
def celsius_to_fahrenheit (number):
    return (number * 9/5) + 32
print(celsius_to_fahrenheit(int(0)))
print(celsius_to_fahrenheit(int(100)))
print(celsius_to_fahrenheit(int(37)))
# Out:
# 32.0
# 212.0
# 98.6

# %%
def full_name (firstname, lastname):
    return f"{firstname} {lastname}"

print(full_name("Adharsh", "Vaiapuri"))
print(full_name("John", "Doe"))
print(full_name("Jane", "Smith"))
# Out:
# Adharsh Vaiapuri
# John Doe
# Jane Smith

# %%
def age_category(number):
    if number <= 12:
        return "child"
    elif number <= 17:
        return "teenager"
    elif number <= 64:
        return "adult"
    else:
        return "senior"

print(age_category(12))
print(age_category(15))
print(age_category(28))
print(age_category(70))
# Out:
# child
# teenager
# adult
# senior

# %%
def rectangle_area(length, width):
    area = length * width
    return area
print(rectangle_area(5, 3))   
print(rectangle_area(10, 2))
print(rectangle_area(7, 7))
# Out:
# 15
# 20
# 49

# %%
def times_table (number):
    for i in range(1, 11):
        print(f"{number} * {i} = {number * i}")

times_table(3)
# Out:
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30

# %%
def traingle (number):
    for i in range(1, number +1):
        print("*" * i)

traingle(5)
# Out:
# *
# **
# ***
# ****
# *****

# %%
def traingle (number):
    for i in range(1, number +1):
        print("*" * i)

traingle(5)
# Out:
# *
# **
# ***
# ****
# *****
